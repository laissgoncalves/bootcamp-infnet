# %%
import pandas as pd 
import numpy as np
import matplotlib as plt

# %%
url = 'https://raw.githubusercontent.com/CharlesPrado23/Bootcamp_TurmaNoite/main/Pandas/Life%20Expectancy%20Data.csv'

# %%
df= pd.read_csv(url)
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df['Life expectancy '].plot.bar()
# Out:
# <Axes: >

# %%
df.plot(x='Year',y='Life expectancy ', kind= 'scatter')
# Out:
# <Axes: xlabel='Year', ylabel='Life expectancy '>

# %%
df2 = df[df['Status']=='Developing']
df2
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df3 = df[df['Status']=='Developed']
df3
# Out:
#                        Country  Year     Status  Life expectancy   \
# 112                  Australia  2015  Developed              82.8
# 113                  Australia  2014  Developed              82.7
# 114                  Australia  2013  Developed              82.5
# 115                  Australia  2012  Developed              82.3
# 116                  Australia  2011  Developed              82.0
# ...                        ...   ...        ...               ...
# 2805  United States of America  2004  Developed              77.5
# 2806  United States of America  2003  Developed              77.2
# 2807  United States of America  2002  Developed              77.0
# 2808  United States of America  2001  Developed              76.9
# 2809  United States of America  2000  Developed              76.8
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 112              59.0              1      NaN                 0.00000
# ...

# %%
df2.plot(x='Year',y='Life expectancy ', kind= 'scatter')
# Out:
# <Axes: xlabel='Year', ylabel='Life expectancy '>

# %%
df3.plot(x='Year',y='Life expectancy ', kind= 'scatter')
# Out:
# <Axes: xlabel='Year', ylabel='Life expectancy '>

# %%
df2['Life expectancy '].mean()
# Out:
# 67.11146523178809

# %%
df3['Life expectancy '].mean()
# Out:
# 79.1978515625

# %%
mean_df2 = df2.groupby('Year')['Life expectancy '].mean()
mean_df2.plot() # desenvolvimento
# Out:
# <Axes: xlabel='Year'>

# %%
mean_df3 = df3.groupby('Year')['Life expectancy '].mean()
mean_df3.plot() #desenvolvido
# Out:
# <Axes: xlabel='Year'>

# %%
df4 = pd.DataFrame()
df4['Developing'] = mean_df2
df4['Developed'] = mean_df3
df4
# Out:
#       Developing  Developed
# Year
# 2000   64.619868  76.803125
# 2001   65.009934  77.128125
# 2002   65.190728  77.546875
# 2003   65.206623  77.940625
# 2004   65.370861  78.384375
# 2005   66.009272  78.590625
# 2006   66.450331  79.131250
# 2007   66.860927  79.300000
# 2008   67.413907  78.931250
# 2009   67.894040  79.584375
# 2010   67.908609  80.146875
# 2011   68.523841  80.706250
# 2012   68.898013  80.443750
# 2013   69.234437  80.681250
# 2014   69.501987  81.137500
# 2015   69.690066  80.709375

# %%
df4.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
df.corr(numeric_only= True)
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.170033        -0.079052
# Life expectancy                  0.170033          1.000000        -0.696359
# Adult Mortality                 -0.079052         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196557         0.078756
# Alcohol                         -0.052990          0.404877        -0.195848
# percentage expenditure           0.031400          0.381864        -0.242860
# Hepatitis B                      0.104333          0.256762        -0.162476
# Measles                         -0.082493         -0.157586         0.031176
#  BMI                             0.108974          0.567694        -0.387017
# under-five deaths               -0.042937         -0.222529         0.094146
# Polio                            0.094158          0.465556        -0.274823
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))

sns.heatmap(df2.corr(numeric_only= True))
# verificar as correlações em preto.
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))

sns.heatmap(df3.corr(numeric_only= True))
# tem algo de errado no grafico na parte do hiv tudo branco
# Out:
# <Axes: >

# %%
pip install seaborn
# Out:
# ...
#
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install git+https://github.com/polakowo/vectorbt
# Out:
# ...
#   Cloning https://github.com/polakowo/vectorbt to c:\users\laiss\appdata\local\temp\pip-req-build-y5_fdjfi
#   Resolved https://github.com/polakowo/vectorbt to commit 2ee26a4c34678a6df6774dfab7bd16ffb2389cd6
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached scipy-1.11.4-cp311-cp311-win_amd64.whl (44.1 MB)
# ...
#   Using cached plotly-5.18.0-py3-none-any.whl (15.6 MB)
# ...
#   Using cached ipywidgets-8.1.1-py3-none-any.whl (139 kB)
# ...
#   Using cached dill-0.3.7-py3-none-any.whl (115 kB)
# ...
#   Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# ...
#   Using cached dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
# ...
#   Using cached imageio-2.33.1-py3-none-any.whl (313 kB)
# ...
#   Using cached scikit_learn-1.4.0-1-cp311-cp311-win_amd64.whl (10.6 MB)
# ...
#   Using cached schedule-1.2.1-py2.py3-none-any.whl (11 kB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# ...

# %%
# !python -m pip install --upgrade pip
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 7.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# ...
#   WARNING: The scripts pip.exe, pip3.11.exe and pip3.exe are installed in 'c:\Users\laiss\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# depois daqui teve o time das aulas 29/08, 30/08

# %%
# apartir da aula 31/08

# %%
alea= np.array(range(1,101))

# %%
pip install vectorbt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
mu, sigma = 10, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
#aprender a fazer histograma , para verificar se a quantidade de dados estao suficientes, pois existem valores
